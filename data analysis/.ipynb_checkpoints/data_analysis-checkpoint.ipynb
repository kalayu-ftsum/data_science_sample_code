# %% [markdown]
# # 1. importing pandas and loading data

# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# 64452            NaN          India          NaN            NaN
# 64453            NaN       Thailand          NaN            NaN
# 64454            NaN        Morocco          NaN            NaN
# 64455            NaN    Netherlands          NaN            NaN
# 64456            NaN  United States          NaN            NaN
# 64457            NaN        Morocco          NaN            NaN
# 64458            NaN       Viet Nam          NaN            NaN
# 64459            NaN         Poland          NaN            NaN
# 64460            NaN          Spain          NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                               Microsoft SQL Server
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                       MariaDB;Microsoft SQL Server
#
#                                       DatabaseWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459                                             Oracle
# 64460          MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                  DevType  \
# 64451      Data scientist or machine learning specialist
# 64452                                                NaN
# 64453  Data or business analyst;Developer, mobile;Sen...
# 64454                                                NaN
# 64455                                                NaN
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                                EdLevel  \
# 64451  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64452                                              NaN
# 64453                        Primary/elementary school
# 64454           I never completed any formal education
# 64455                                              NaN
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                Employment Ethnicity Gender JobFactors JobSat  \
# 64451  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64452                  Employed full-time       NaN    NaN        NaN    NaN
# 64453  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64454                             Student       NaN    NaN        NaN    NaN
# 64455  Not employed, but looking for work       NaN    NaN        NaN    NaN
# 64456                  Employed full-time       NaN    NaN        NaN    NaN
# 64457                  Employed full-time       NaN    NaN        NaN    NaN
# 64458                                 NaN       NaN    NaN        NaN    NaN
# 64459                  Employed full-time       NaN    NaN        NaN    NaN
# 64460                  Employed full-time       NaN    NaN        NaN    NaN
#
#       JobSeek                             LanguageDesireNextYear  \
# 64451     NaN                                                NaN
# 64452     NaN                                                NaN
# 64453     NaN                                       C++;HTML/CSS
# 64454     NaN                                                NaN
# 64455     NaN                                               Java
# 64456     NaN                                                NaN
# 64457     NaN  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458     NaN                                                NaN
# 64459     NaN                           HTML/CSS;Java;JavaScript
# 64460     NaN                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 64451                                                NaN
# 64452                                                NaN
# 64453                                       C++;HTML/CSS
# 64454                                                NaN
# 64455                                                NaN
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#       MiscTechDesireNextYear MiscTechWorkedWith NEWCollabToolsDesireNextYear  \
# 64451                    NaN                NaN                          NaN
# 64452                    NaN                NaN                          NaN
# 64453                   .NET               .NET                          NaN
# 64454                    NaN                NaN                          NaN
# 64455                Ansible                NaN                          NaN
# 64456                    NaN                NaN                          NaN
# 64457                    NaN                NaN                          NaN
# 64458                    NaN                NaN                          NaN
# 64459                Node.js                NaN                Github;Gitlab
# 64460      .NET Core;Xamarin     .NET;.NET Core       Github;Microsoft Teams
#
#                     NEWCollabToolsWorkedWith NEWDevOps NEWDevOpsImpt  \
# 64451                                    NaN       NaN           NaN
# 64452                                    NaN       NaN           NaN
# 64453                                    NaN       NaN           NaN
# 64454                                    NaN       NaN           NaN
# 64455                                 Github       NaN           NaN
# 64456                                    NaN       NaN           NaN
# 64457                                    NaN       NaN           NaN
# 64458                                    NaN       NaN           NaN
# 64459  Confluence;Jira;Slack;Microsoft Teams       NaN           NaN
# 64460                                 Github       NaN           NaN
#
#                   NEWEdImpt NEWJobHunt NEWJobHuntResearch       NEWLearn  \
# 64451      Fairly important        NaN                NaN            NaN
# 64452                   NaN        NaN                NaN            NaN
# 64453        Very important        NaN                NaN    Once a year
# 64454                   NaN        NaN                NaN            NaN
# 64455                   NaN        NaN                NaN            NaN
# 64456        Very important        NaN                NaN  Once a decade
# 64457                   NaN        NaN                NaN            NaN
# 64458                   NaN        NaN                NaN            NaN
# 64459                   NaN        NaN                NaN    Once a year
# 64460  Critically important        NaN                NaN    Once a year
#
#       NEWOffTopic NEWOnboardGood NEWOtherComms NEWOvertime  \
# 64451         NaN            NaN           NaN         NaN
# 64452         NaN            NaN           NaN         NaN
# 64453         NaN            NaN           NaN         NaN
# 64454         NaN            NaN           NaN         NaN
# 64455         NaN            NaN           NaN         NaN
# 64456         NaN            NaN           NaN         NaN
# 64457         NaN            NaN           NaN         NaN
# 64458         NaN            NaN           NaN         NaN
# 64459         NaN            NaN           NaN         NaN
# 64460         NaN            NaN           NaN         NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 64451                                                NaN                NaN
# 64452                                                NaN                NaN
# 64453                                 Start a free trial  Hello, old friend
# 64454                                                NaN                NaN
# 64455                                                NaN                NaN
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 64451   Stack Overflow (public Q&A for anyone who codes)
# 64452                                                NaN
# 64453  Stack Overflow for Teams (private Q&A for orga...
# 64454   Stack Overflow (public Q&A for anyone who codes)
# 64455                                                NaN
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck    OpSys OrgSize  \
# 64451                                                NaN      NaN     NaN
# 64452                                                NaN      NaN     NaN
# 64453                       Watch help / tutorial videos    MacOS     NaN
# 64454                                                NaN      NaN     NaN
# 64455                                                NaN      NaN     NaN
# 64456                          Call a coworker or friend  Windows     NaN
# 64457                                                NaN      NaN     NaN
# 64458                                                NaN      NaN     NaN
# 64459     Call a coworker or friend;Visit Stack Overflow  Windows     NaN
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...  Windows     NaN
#
#                    PlatformDesireNextYear  \
# 64451                                 NaN
# 64452                                 NaN
# 64453                                 iOS
# 64454                                 NaN
# 64455                             Android
# 64456                                 NaN
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460  Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith PurchaseWhat Sexuality  \
# 64451                                         NaN          NaN       NaN
# 64452                                         NaN          NaN       NaN
# 64453                                         iOS          NaN       NaN
# 64454                                         NaN          NaN       NaN
# 64455                                         NaN          NaN       NaN
# 64456                                         NaN          NaN       NaN
# 64457                                         NaN          NaN       NaN
# 64458                                         NaN          NaN       NaN
# 64459                               Linux;Windows          NaN       NaN
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows          NaN       NaN
#
#                      SOAccount          SOComm SOPartFreq  \
# 64451                      Yes             NaN        NaN
# 64452                      NaN             NaN        NaN
# 64453                      NaN             NaN        NaN
# 64454  Not sure/can't remember  No, not really        NaN
# 64455                      NaN             NaN        NaN
# 64456                      NaN             NaN        NaN
# 64457                      NaN             NaN        NaN
# 64458                      NaN             NaN        NaN
# 64459                      NaN             NaN        NaN
# 64460                      NaN             NaN        NaN
#
#                                SOVisitFreq SurveyEase SurveyLength Trans  \
# 64451      A few times per month or weekly        NaN          NaN   NaN
# 64452                                  NaN        NaN          NaN   NaN
# 64453                                  NaN        NaN          NaN   NaN
# 64454  Less than once per month or monthly        NaN          NaN   NaN
# 64455                                  NaN        NaN          NaN   NaN
# 64456                                  NaN        NaN          NaN   NaN
# 64457                                  NaN        NaN          NaN   NaN
# 64458                                  NaN        NaN          NaN   NaN
# 64459                                  NaN        NaN          NaN   NaN
# 64460                                  NaN        NaN          NaN   NaN
#
#                                           UndergradMajor  \
# 64451  Another engineering discipline (such as civil,...
# 64452                                                NaN
# 64453                                                NaN
# 64454                                                NaN
# 64455                                                NaN
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 64451                          NaN                                     NaN
# 64452                          NaN                                     NaN
# 64453                          NaN                                     NaN
# 64454                          NaN                                     NaN
# 64455                          NaN                            ASP.NET Core
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                  WelcomeChange  WorkWeekHrs YearsCode  \
# 64451                                      NaN          NaN         2
# 64452                                      NaN          NaN       NaN
# 64453                                      NaN          NaN         3
# 64454  Just as welcome now as I felt last year          NaN         3
# 64455                                      NaN          NaN       NaN
# 64456                                      NaN          NaN        10
# 64457                                      NaN          NaN       NaN
# 64458                                      NaN          NaN       NaN
# 64459                                      NaN          NaN       NaN
# 64460                                      NaN          NaN       NaN
#
#            YearsCodePro
# 64451               NaN
# 64452               NaN
# 64453               NaN
# 64454               NaN
# 64455               NaN
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN

# %%
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp         Country    CurrencyDesc  \
# 0  Monthly        NaN            NaN         Germany   European Euro
# 1      NaN        NaN            NaN  United Kingdom  Pound sterling
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
#
#                                           JobFactors              JobSat  \
# 0  Languages, frameworks, and other technologies ...  Slightly satisfied
# 1                                                NaN   Very dissatisfied
#
#                                         JobSeek  LanguageDesireNextYear  \
# 0  I am not interested in new job opportunities  C#;HTML/CSS;JavaScript
# 1  I am not interested in new job opportunities            Python;Swift
#
#        LanguageWorkedWith            MiscTechDesireNextYear  \
# 0  C#;HTML/CSS;JavaScript                 .NET Core;Xamarin
# 1        JavaScript;Swift  React Native;TensorFlow;Unity 3D
#
#   MiscTechWorkedWith            NEWCollabToolsDesireNextYear  \
# 0     .NET;.NET Core  Microsoft Teams;Microsoft Azure;Trello
# 1       React Native                            Github;Slack
#
#                        NEWCollabToolsWorkedWith NEWDevOps       NEWDevOpsImpt  \
# 0  Confluence;Jira;Slack;Microsoft Azure;Trello        No  Somewhat important
# 1           Confluence;Jira;Github;Gitlab;Slack       NaN                 NaN
#
#           NEWEdImpt NEWJobHunt NEWJobHuntResearch     NEWLearn NEWOffTopic  \
# 0  Fairly important        NaN                NaN  Once a year    Not sure
# 1  Fairly important        NaN                NaN  Once a year    Not sure
#
#   NEWOnboardGood NEWOtherComms                       NEWOvertime  \
# 0            NaN            No  Often: 1-2 days per week or more
# 1            NaN            No                               NaN
#
#                                  NEWPurchaseResearch NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...        Amused
# 1                                                NaN        Amused
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck    OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...  Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...    MacOS
#
#                     OrgSize                          PlatformDesireNextYear  \
# 0          2 to 9 employees  Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1  1,000 to 4,999 employees                      iOS;Kubernetes;Linux;MacOS
#
#   PlatformWorkedWith                   PurchaseWhat                Sexuality  \
# 0            Windows                            NaN  Straight / Heterosexual
# 1                iOS  I have little or no influence                      NaN
#
#   SOAccount           SOComm                           SOPartFreq  \
# 0        No   No, not at all                                  NaN
# 1       Yes  Yes, definitely  Less than once per month or monthly
#
#               SOVisitFreq                  SurveyEase           SurveyLength  \
# 0  Multiple times per day  Neither easy nor difficult  Appropriate in length
# 1  Multiple times per day                         NaN                    NaN
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
#
#                               WelcomeChange  WorkWeekHrs YearsCode  \
# 0   Just as welcome now as I felt last year         50.0        36
# 1  Somewhat more welcome now than last year          NaN         7
#
#   YearsCodePro
# 0           27
# 1            4

# %%
df.shape
# Out:
# (64461, 61)

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df.head(10)
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3            Age  What is your age (in years)? If you prefer not...
# 4     Age1stCode  At what age did you write your first line of c...
# 5       CompFreq   Is that compensation weekly, monthly, or yearly?
# 6      CompTotal  What is your current total compensation (salar...
# 7  ConvertedComp  Salary converted to annual USD salaries using ...
# 8        Country                                 Where do you live?
# 9   CurrencyDesc  Which currency do you use day-to-day? If your ...

# %% [markdown]
# # 2. DataFrames and Series

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
type(people)
# Out:
# dict

# %%
df_test = pd.DataFrame(people)

# %%
df_test
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
type(df_test)
# Out:
# pandas.core.frame.DataFrame

# %%
df_test['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_test.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_test[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df_test.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df_test.iloc[[0, 1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df_test.loc[[0, 1], ['email', 'last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %% [markdown]
# ## test on real data

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
type(df['Hobbyist'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2,3]
# Out:
# 0   NaN
# 1   NaN
# Name: Age, dtype: float64

# %%
df.iloc[0:2,[3,5,6]]
# Out:
#    Age CompFreq  CompTotal
# 0  NaN  Monthly        NaN
# 1  NaN      NaN        NaN

# %%
df.iloc[0:2,3:6]
# Out:
#    Age Age1stCode CompFreq
# 0  NaN         13  Monthly
# 1  NaN         19      NaN

# %%
df.loc[0:2,"Age"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# Name: Age, dtype: float64

# %%
df.loc[0:2,["Age","CompFreq","CompTotal"]]
# Out:
#    Age CompFreq  CompTotal
# 0  NaN  Monthly        NaN
# 1  NaN      NaN        NaN
# 2  NaN      NaN        NaN

# %%
df.loc[0:2,"Age":"CompTotal"]
# Out:
#    Age Age1stCode CompFreq  CompTotal
# 0  NaN         13  Monthly        NaN
# 1  NaN         19      NaN        NaN
# 2  NaN         15      NaN        NaN

# %% [markdown]
# # 3. Indexes

# %%
df_test.set_index('email',inplace=True)

# %%
df_test
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df_test.loc['CoreyMSchafer@gmail.com':"JaneDoe@email.com", 'last']
# Out:
# email
# CoreyMSchafer@gmail.com    Schafer
# JaneDoe@email.com              Doe
# Name: last, dtype: object

# %%
df_test.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
df_test.reset_index(inplace=True)
df_test
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %% [markdown]
# ## applying on real data

# %%
schema_df.set_index('Column', inplace=True)
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
schema_df.reset_index(inplace=True)
schema_df.head()
# Out:
#           Column                                       QuestionText
# 0            Age  What is your age (in years)? If you prefer not...
# 1     Age1stCode  At what age did you write your first line of c...
# 2       CompFreq   Is that compensation weekly, monthly, or yearly?
# 3      CompTotal  What is your current total compensation (salar...
# 4  ConvertedComp  Salary converted to annual USD salaries using ...

# %% [markdown]
# # 4. Filtering

# %%
df_test
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
filter=(df_test['last'] == 'Schafer') | (df_test['first'] == 'John')
df_test.loc[~filter]
# Out:
#                email first last
# 1  JaneDoe@email.com  Jane  Doe

# %% [markdown]
# ## working on real data

# %%
country=["Ethiopia","United States","United Kingdom"]
filt=df["Country"].isin(country)
df[filt]["Country"].value_counts()
# Out:
# United States     12469
# United Kingdom     3896
# Ethiopia             59
# Name: Country, dtype: int64

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt]['LanguageWorkedWith'].head()
# Out:
# 2                             Objective-C;Python;Swift
# 7                                           Python;SQL
# 9                  HTML/CSS;Java;JavaScript;Python;SQL
# 12                                 C;JavaScript;Python
# 14    Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# Name: LanguageWorkedWith, dtype: object

# %% [markdown]
# # 5. updating rows and columns

# %%
df_test.columns = ['first_name', 'last_name', 'email']
df_test
# Out:
#                 first_name last_name    email
# 0  CoreyMSchafer@gmail.com     Corey  Schafer
# 1        JaneDoe@email.com      Jane      Doe
# 2        JohnDoe@email.com      John      Doe

# %%
df_test.columns = [x.lower() for x in df_test.columns]
df_test
# Out:
#                 first_name last_name    email
# 0  CoreyMSchafer@gmail.com     Corey  Schafer
# 1        JaneDoe@email.com      Jane      Doe
# 2        JohnDoe@email.com      John      Doe

# %%
df_test.rename(columns={"first_name":"first", "last_name":"last"}, inplace=True)

# %%
df_test.loc[2]=['John', 'Smith', 'JohnSmith@email.com']
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              Schafer
# 1        JaneDoe@email.com   Jane                  Doe
# 2                     John  Smith  JohnSmith@email.com

# %%
df_test.columns=["first", "last","email"]

# %%
df_test.loc[2,"last"]='ftsum'
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              Schafer
# 1        JaneDoe@email.com   Jane                  Doe
# 2                     John  ftsum  JohnSmith@email.com

# %%
df_test.at[2, 'last'] = 'Doe'
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              Schafer
# 1        JaneDoe@email.com   Jane                  Doe
# 2                     John    Doe  JohnSmith@email.com

# %%
filt = (df_test['email'] == 'JohnDoe@email.com')
df_test.loc[filt, 'last'] = 'Smith'

# %%
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              Schafer
# 1        JaneDoe@email.com   Jane                  Doe
# 2                     John    Doe  JohnSmith@email.com

# %%
df_test['email'] = df_test['email'].str.lower()
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              schafer
# 1        JaneDoe@email.com   Jane                  doe
# 2                     John    Doe  johnsmith@email.com

# %%
df_test['email'].apply(len)
# Out:
# 0     7
# 1     3
# 2    19
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df_test['email']=df_test['email'].apply(update_email)
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              SCHAFER
# 1        JaneDoe@email.com   Jane                  DOE
# 2                     John    Doe  JOHNSMITH@EMAIL.COM

# %%
df_test['email'] = df_test['email'].apply(lambda x: x.lower())
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              schafer
# 1        JaneDoe@email.com   Jane                  doe
# 2                     John    Doe  johnsmith@email.com

# %%
df_test.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df_test.apply(pd.Series.min)
# Out:
# first    CoreyMSchafer@gmail.com
# last                       Corey
# email                        doe
# dtype: object

# %%
df_test.applymap(str.lower)
# Out:
#                      first   last                email
# 0  coreymschafer@gmail.com  corey              schafer
# 1        janedoe@email.com   jane                  doe
# 2                     john    doe  johnsmith@email.com

# %%
df_test['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: first, dtype: object

# %%
df_test['first'] = df_test['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
df_test
# Out:
#                      first   last                email
# 0  CoreyMSchafer@gmail.com  Corey              schafer
# 1        JaneDoe@email.com   Jane                  doe
# 2                     John    Doe  johnsmith@email.com

# %% [markdown]
# ## applying on real data

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 64456   NaN
# 64457   NaN
# 64458   NaN
# 64459   NaN
# 64460   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df.rename(columns={'SalaryUSD':'ConvertedComp'}, inplace=True)
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 64456     True
# 64457     True
# 64458     True
# 64459     True
# 64460     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession     True
# 1           2                     I am a developer by profession    False
# 2           3                        I code primarily as a hobby     True
# 3           4                     I am a developer by profession     True
# 4           5  I used to be a developer by profession, but no...     True
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %% [markdown]
# # 6 Add and Remove rows and columns

# %%
df_test.rename(columns={"first":'email','email':'first'},inplace=True)

df_test['first'] + ' '+ df_test['last']
# Out:
# 0              schafer Corey
# 1                   doe Jane
# 2    johnsmith@email.com Doe
# dtype: object

# %%
df_test['full_name']=df_test['first'] + ' '+ df_test['last']

# %%
df_test.drop(index=2, inplace=True)

# %%
df_test.drop(columns=["first", "last"],inplace=True)

# %%
df_test[['first','last']]=df_test['full_name'].str.split(' ', expand=True)

# %%
df_test
# Out:
#                      email      full_name    first   last
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey
# 1        JaneDoe@email.com       doe Jane      doe   Jane

# %%
filt = df_test['last'] == 'Doe'
df_test.drop(index=df_test[filt].index)
# Out:
#                      email      full_name    first   last
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey
# 1        JaneDoe@email.com       doe Jane      doe   Jane

# %%
df_test.append({'first': 'Tony'}, ignore_index=True)
# Out:
#                      email      full_name    first   last
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey
# 1        JaneDoe@email.com       doe Jane      doe   Jane
# 2                      NaN            NaN     Tony    NaN

# %%
people = {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df_test.append(df2, ignore_index=True, sort=False)
# Out:
#                      email      full_name    first    last
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer   Corey
# 1        JaneDoe@email.com       doe Jane      doe    Jane
# 2       IronMan@avenge.com            NaN     Tony   Stark
# 3           Cap@avenge.com            NaN    Steve  Rogers

# %% [markdown]
# # 7 Sorting

# %%
df_test.sort_values(by='last', ascending=False)
# Out:
#                      email      full_name    first   last
# 1        JaneDoe@email.com       doe Jane      doe   Jane
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey

# %%
df_test.sort_values(by=['last', 'first'], ascending=False)
# Out:
#                      email      full_name    first   last
# 1        JaneDoe@email.com       doe Jane      doe   Jane
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey

# %%
df_test.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df_test.sort_index()
# Out:
#                      email      full_name    first   last
# 0  CoreyMSchafer@gmail.com  schafer Corey  schafer  Corey
# 1        JaneDoe@email.com       doe Jane      doe   Jane

# %%
df_test['last'].sort_values()
# Out:
# 0    Corey
# 1     Jane
# Name: last, dtype: object

# %% [markdown]
# ##  applying on real data

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(10)
# Out:
#            Country  ConvertedComp
# 61540  Afghanistan      1000000.0
# 63925  Afghanistan      1000000.0
# 63993  Afghanistan      1000000.0
# 38261  Afghanistan       231192.0
# 28270  Afghanistan       130000.0
# 9806   Afghanistan        23328.0
# 62520  Afghanistan        23328.0
# 50812  Afghanistan        20950.0
# 50469  Afghanistan        20220.0
# 43642  Afghanistan        18660.0

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 5701     2000000.0
# 53175    2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 121      2000000.0
# 123      2000000.0
# 191      2000000.0
# 663      2000000.0
# 697      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5701         5725                     I am a developer by profession    False
# 53175       54263                     I am a developer by profession     True
# 42657       43430                     I am a developer by profession     True
# 58136       59279                     I am a developer by profession     True
# 45753       46711                     I am a developer by profession     True
# 121           123                     I am a developer by profession     True
# 123           125  I am not primarily a developer, but I write co...     True
# 191           193                     I am a developer by profession     True
# 663           665                     I am a developer by profession     True
# 697           699  I am not primarily a developer, but I write co...     True
#
#         Age            Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 5701   26.0                    14  Monthly  1.800000e+05      2000000.0
# 53175  29.0                    10   Weekly  7.000000e+04      2000000.0
# 42657  33.0                    17  Monthly  1.710000e+05      2000000.0
# 58136   NaN                    12  Monthly  3.000000e+05      2000000.0
# 45753   NaN  Younger than 5 years   Yearly  1.000000e+56      2000000.0
# 121    26.0                    12   Weekly  1.200000e+05      2000000.0
# 123    41.0                    30  Monthly  2.000000e+05      2000000.0
# 191    29.0                    16   Weekly  1.200000e+05      2000000.0
# 663    24.0                    13   Weekly  1.500000e+05      2000000.0
# 697    39.0                    16   Weekly  5.200000e+04      2000000.0
#
#              Country          CurrencyDesc CurrencySymbol  \
# 5701          Canada  United States dollar            USD
# 53175         Canada  United States dollar            USD
# 42657          Italy  United States dollar            USD
# 58136          Nepal  United States dollar            USD
# 45753        Nomadic  United States dollar            USD
# 121    United States  United States dollar            USD
# 123    United States  United States dollar            USD
# 191    United States  United States dollar            USD
# 663    United States  United States dollar            USD
# 697    United States  United States dollar            USD
#
#                                   DatabaseDesireNextYear  \
# 5701                                               Redis
# 53175                                              Redis
# 42657                                                NaN
# 58136  Cassandra;Couchbase;DynamoDB;IBM DB2;MariaDB;M...
# 45753  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 121          Cassandra;Firebase;MongoDB;PostgreSQL;Redis
# 123                                           PostgreSQL
# 191                                                  NaN
# 663                                                  NaN
# 697        MariaDB;Microsoft SQL Server;MySQL;PostgreSQL
#
#                                       DatabaseWorkedWith  \
# 5701                                                 NaN
# 53175                         Firebase;PostgreSQL;SQLite
# 42657                                                NaN
# 58136  Elasticsearch;Firebase;Microsoft SQL Server;My...
# 45753  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 121                                            Cassandra
# 123                                           PostgreSQL
# 191                                                  NaN
# 663                                           PostgreSQL
# 697                           Microsoft SQL Server;MySQL
#
#                                                  DevType  \
# 5701               Developer, back-end;DevOps specialist
# 53175                                  Developer, mobile
# 42657  Academic researcher;Developer, back-end;Develo...
# 58136  Data or business analyst;Data scientist or mac...
# 45753  Academic researcher;Data or business analyst;D...
# 121            Developer, back-end;Developer, full-stack
# 123    Data scientist or machine learning specialist;...
# 191                                    Developer, mobile
# 663                                 Developer, front-end
# 697                                 System administrator
#
#                                                EdLevel  \
# 5701      Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 53175     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42657       Other doctoral degree (Ph.D., Ed.D., etc.)
# 58136  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45753                        Primary/elementary school
# 121       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 123         Other doctoral degree (Ph.D., Ed.D., etc.)
# 191    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 663       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 697       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  \
# 5701                                  Employed full-time
# 53175                                 Employed full-time
# 42657                                 Employed full-time
# 58136                                 Employed full-time
# 45753                                 Employed full-time
# 121                                   Employed full-time
# 123                                   Employed full-time
# 191                                   Employed full-time
# 663                                   Employed full-time
# 697    Independent contractor, freelancer, or self-em...
#
#                                   Ethnicity Gender  \
# 5701           White or of European descent    Man
# 53175                           South Asian    Man
# 42657          White or of European descent    Man
# 58136           South Asian;Southeast Asian    NaN
# 45753                                   NaN    NaN
# 121            White or of European descent    Man
# 123            White or of European descent    Man
# 191            White or of European descent    Man
# 663    Black or of African descent;Biracial  Woman
# 697            White or of European descent    Man
#
#                                               JobFactors  \
# 5701   Languages, frameworks, and other technologies ...
# 53175  Flex time or a flexible schedule;Languages, fr...
# 42657  Languages, frameworks, and other technologies ...
# 58136  Flex time or a flexible schedule;Remote work o...
# 45753  Languages, frameworks, and other technologies ...
# 121    Languages, frameworks, and other technologies ...
# 123    Flex time or a flexible schedule;Family friend...
# 191    Specific department or team I’d be working on;...
# 663    Diversity of the company or organization;Flex ...
# 697    Diversity of the company or organization;Offic...
#
#                                    JobSat  \
# 5701                   Slightly satisfied
# 53175                  Slightly satisfied
# 42657                      Very satisfied
# 58136                      Very satisfied
# 45753                      Very satisfied
# 121    Neither satisfied nor dissatisfied
# 123                        Very satisfied
# 191                        Very satisfied
# 663                        Very satisfied
# 697                    Slightly satisfied
#
#                                                  JobSeek  \
# 5701        I am not interested in new job opportunities
# 53175  I’m not actively looking, but I am open to new...
# 42657       I am not interested in new job opportunities
# 58136  I’m not actively looking, but I am open to new...
# 45753  I’m not actively looking, but I am open to new...
# 121    I’m not actively looking, but I am open to new...
# 123         I am not interested in new job opportunities
# 191    I’m not actively looking, but I am open to new...
# 663         I am not interested in new job opportunities
# 697                      I am actively looking for a job
#
#                                   LanguageDesireNextYear  \
# 5701                           Go;Python;Ruby;TypeScript
# 53175                                    Go;Haskell;Rust
# 42657   Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 58136  Dart;Go;Haskell;Julia;Kotlin;Perl;PHP;R;Ruby;R...
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 121                                 C;C++;Go;Kotlin;Rust
# 123                                               Python
# 191                                    Objective-C;Swift
# 663                       HTML/CSS;JavaScript;TypeScript
# 697    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
#
#                                       LanguageWorkedWith  \
# 5701             Bash/Shell/PowerShell;JavaScript;Python
# 53175      Dart;Java;JavaScript;Kotlin;Python;TypeScript
# 42657   Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 58136  Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 45753  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 121             Bash/Shell/PowerShell;C++;Go;Java;Python
# 123                                           Python;SQL
# 191                    Java;JavaScript;Objective-C;Swift
# 663                      HTML/CSS;JavaScript;Python;Ruby
# 697    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
#
#                                   MiscTechDesireNextYear  \
# 5701                                            Teraform
# 53175              React Native;TensorFlow;Torch/PyTorch
# 42657                                                NaN
# 58136  Ansible;Apache Spark;Flutter;Hadoop;Keras;Pand...
# 45753  .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 121              Flutter;Hadoop;TensorFlow;Unreal Engine
# 123                Keras;Pandas;TensorFlow;Torch/PyTorch
# 191                                                  NaN
# 663                                              Node.js
# 697           .NET;.NET Core;Pandas;Puppet;Unreal Engine
#
#                                       MiscTechWorkedWith  \
# 5701                                                 NaN
# 53175                                    Flutter;Node.js
# 42657                                                NaN
# 58136  .NET;.NET Core;Chef;Cordova;Node.js;React Nati...
# 45753  .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 121                                            .NET Core
# 123                              Keras;Pandas;TensorFlow
# 191                                                  NaN
# 663                                              Node.js
# 697                                                  NaN
#
#                             NEWCollabToolsDesireNextYear  \
# 5701        Github;Gitlab;Google Suite (Docs, Meet, etc)
# 53175                                 Facebook Workplace
# 42657  Confluence;Jira;Github;Gitlab;Slack;Google Sui...
# 58136                                      Gitlab;Trello
# 45753  Confluence;Jira;Github;Gitlab;Facebook Workpla...
# 121                         Confluence;Jira;Github;Slack
# 123                                                 Jira
# 191    Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 663     Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 697    Microsoft Teams;Microsoft Azure;Trello;Google ...
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 5701               Github;Google Suite (Docs, Meet, etc)       Yes
# 53175  Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 42657  Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 58136  Confluence;Jira;Github;Facebook Workplace;Slac...       Yes
# 45753  Confluence;Jira;Github;Gitlab;Facebook Workpla...       Yes
# 121    Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 123                                                 Jira  Not sure
# 191    Github;Gitlab;Slack;Microsoft Teams;Trello;Goo...        No
# 663     Jira;Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 697    Jira;Microsoft Teams;Microsoft Azure;Trello;Go...        No
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 5701   Extremely important                      Very important
# 53175  Extremely important                  Somewhat important
# 42657   Somewhat important                    Fairly important
# 58136  Extremely important                                 NaN
# 45753  Extremely important  Not at all important/not necessary
# 121     Somewhat important                      Very important
# 123                Neutral                Critically important
# 191                Neutral                    Fairly important
# 663    Extremely important                  Somewhat important
# 697     Somewhat important                Critically important
#
#                                               NEWJobHunt  \
# 5701   Trouble with my teammates;Better work/life bal...
# 53175  Just because;Curious about other opportunities...
# 42657  Curious about other opportunities;Better compe...
# 58136  Having a bad day (or week or month) at work;Tr...
# 45753  Just because;Having a bad day (or week or mont...
# 121    Trouble with my direct manager;Trouble with le...
# 123                             Better work/life balance
# 191    Curious about other opportunities;Better compe...
# 663    Better compensation;Trouble with leadership at...
# 697                   Growth or leadership opportunities
#
#                                       NEWJobHuntResearch  \
# 5701   Read company media, such as employee blogs or ...
# 53175  Read company media, such as employee blogs or ...
# 42657  Read company media, such as employee blogs or ...
# 58136  Read company media, such as employee blogs or ...
# 45753  Read company media, such as employee blogs or ...
# 121    Read company media, such as employee blogs or ...
# 123    Personal network - friends or family;Directly ...
# 191    Read company media, such as employee blogs or ...
# 663    Read company media, such as employee blogs or ...
# 697    Read company media, such as employee blogs or ...
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 5701            Once a year          No                           Yes
# 53175      Every few months    Not sure                           Yes
# 42657  Once every few years    Not sure                           Yes
# 58136                   NaN         Yes                           Yes
# 45753      Every few months         NaN                           Yes
# 121             Once a year         Yes                            No
# 123    Once every few years          No                           Yes
# 191        Every few months          No  Onboarding? What onboarding?
# 663             Once a year    Not sure                           Yes
# 697             Once a year         NaN                            No
#
#       NEWOtherComms                                        NEWOvertime  \
# 5701             No                   Often: 1-2 days per week or more
# 53175           Yes                  Rarely: 1-2 days per year or less
# 42657            No                   Often: 1-2 days per week or more
# 58136            No  Sometimes: 1-2 days per month but less than we...
# 45753           NaN                   Often: 1-2 days per week or more
# 121              No                  Rarely: 1-2 days per year or less
# 123              No  Occasionally: 1-2 days per quarter but less th...
# 191              No                                              Never
# 663             Yes  Occasionally: 1-2 days per quarter but less th...
# 697              No                   Often: 1-2 days per week or more
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 5701                                                 NaN  Hello, old friend
# 53175  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 42657                                 Start a free trial        Indifferent
# 58136  Start a free trial;Ask developers I know/work ...             Amused
# 45753                                                NaN  Hello, old friend
# 121    Start a free trial;Ask developers I know/work ...        Indifferent
# 123                                                  NaN             Amused
# 191                                                  NaN  Hello, old friend
# 663                                                  NaN        Indifferent
# 697    Start a free trial;Visit developer communities...  Hello, old friend
#
#                                               NEWSOSites  \
# 5701   Stack Overflow (public Q&A for anyone who code...
# 53175  Stack Overflow (public Q&A for anyone who code...
# 42657   Stack Overflow (public Q&A for anyone who codes)
# 58136  Stack Overflow (public Q&A for anyone who code...
# 45753  Stack Overflow (public Q&A for anyone who code...
# 121    Stack Overflow (public Q&A for anyone who code...
# 123    Stack Overflow (public Q&A for anyone who code...
# 191    Stack Overflow (public Q&A for anyone who code...
# 663    Stack Overflow (public Q&A for anyone who code...
# 697              I have never visited any of these sites
#
#                                                 NEWStuck        OpSys  \
# 5701   Call a coworker or friend;Go for a walk or oth...  Linux-based
# 53175  Meditate;Visit Stack Overflow;Go for a walk or...        MacOS
# 42657  Call a coworker or friend;Go for a walk or oth...  Linux-based
# 58136  Call a coworker or friend;Visit Stack Overflow...      Windows
# 45753  Meditate;Play games;Call a coworker or friend;...          NaN
# 121    Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 123    Visit Stack Overflow;Go for a walk or other ph...      Windows
# 191    Play games;Visit Stack Overflow;Do other work ...        MacOS
# 663    Call a coworker or friend;Visit Stack Overflow...        MacOS
# 697    Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                         OrgSize  \
# 5701   10,000 or more employees
# 53175                       NaN
# 42657  10,000 or more employees
# 58136  1,000 to 4,999 employees
# 45753  10,000 or more employees
# 121    10,000 or more employees
# 123    5,000 to 9,999 employees
# 191          10 to 19 employees
# 663    1,000 to 4,999 employees
# 697        100 to 499 employees
#
#                                   PlatformDesireNextYear  \
# 5701                        Docker;Google Cloud Platform
# 53175                       Docker;Heroku;iOS;Kubernetes
# 42657                        Android;Linux;MacOS;Windows
# 58136  Arduino;Heroku;IBM Cloud or Watson;Kubernetes;...
# 45753  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 121    Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 123                                    Docker;Kubernetes
# 191                                          Android;iOS
# 663    AWS;Google Cloud Platform;Kubernetes;Linux;Mac...
# 697    Android;Arduino;AWS;Google Cloud Platform;Kube...
#
#                                       PlatformWorkedWith  \
# 5701                        Docker;Google Cloud Platform
# 53175                                  Android;AWS;Linux
# 42657                        Android;Linux;MacOS;Windows
# 58136  Android;AWS;Docker;Google Cloud Platform;iOS;L...
# 45753  Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 121                        AWS;Docker;Linux;Raspberry Pi
# 123                                               Docker
# 191                                          Android;iOS
# 663         Google Cloud Platform;Heroku;MacOS;WordPress
# 697                                            WordPress
#
#                            PurchaseWhat                Sexuality  \
# 5701      I have little or no influence  Straight / Heterosexual
# 53175             I have some influence  Straight / Heterosexual
# 42657             I have some influence  Straight / Heterosexual
# 58136  I have a great deal of influence                      NaN
# 45753     I have little or no influence                      NaN
# 121               I have some influence  Straight / Heterosexual
# 123       I have little or no influence  Straight / Heterosexual
# 191       I have little or no influence  Straight / Heterosexual
# 663       I have little or no influence           Bisexual;Queer
# 697                                 NaN  Straight / Heterosexual
#
#                      SOAccount          SOComm  \
# 5701                       Yes  No, not at all
# 53175  Not sure/can't remember   Yes, somewhat
# 42657                      Yes  No, not at all
# 58136                      Yes   Yes, somewhat
# 45753                      NaN             NaN
# 121                        Yes   Yes, somewhat
# 123    Not sure/can't remember  No, not really
# 191                        Yes  No, not really
# 663                        Yes  No, not really
# 697                        NaN             NaN
#
#                                               SOPartFreq  \
# 5701   I have never participated in Q&A on Stack Over...
# 53175                                                NaN
# 42657  I have never participated in Q&A on Stack Over...
# 58136  I have never participated in Q&A on Stack Over...
# 45753                                                NaN
# 121                  Less than once per month or monthly
# 123                                                  NaN
# 191                  Less than once per month or monthly
# 663    I have never participated in Q&A on Stack Over...
# 697                                                  NaN
#
#                            SOVisitFreq                  SurveyEase  \
# 5701   A few times per month or weekly                        Easy
# 53175            Daily or almost daily  Neither easy nor difficult
# 42657  A few times per month or weekly                        Easy
# 58136           Multiple times per day  Neither easy nor difficult
# 45753           Multiple times per day                         NaN
# 121              Daily or almost daily                        Easy
# 123             Multiple times per day                        Easy
# 191               A few times per week  Neither easy nor difficult
# 663    A few times per month or weekly  Neither easy nor difficult
# 697                                NaN  Neither easy nor difficult
#
#                 SurveyLength Trans  \
# 5701               Too short    No
# 53175               Too long    No
# 42657  Appropriate in length    No
# 58136               Too long   NaN
# 45753                    NaN   NaN
# 121    Appropriate in length    No
# 123    Appropriate in length    No
# 191    Appropriate in length    No
# 663    Appropriate in length    No
# 697    Appropriate in length    No
#
#                                           UndergradMajor  \
# 5701   Computer science, computer engineering, or sof...
# 53175  Computer science, computer engineering, or sof...
# 42657  Computer science, computer engineering, or sof...
# 58136  Computer science, computer engineering, or sof...
# 45753                                                NaN
# 121    Computer science, computer engineering, or sof...
# 123                                                  NaN
# 191    Computer science, computer engineering, or sof...
# 663    A humanities discipline (such as literature, h...
# 697    Information systems, information technology, o...
#
#                                   WebframeDesireNextYear  \
# 5701                                              Gatsby
# 53175                                    React.js;Vue.js
# 42657                                                NaN
# 58136                 Django;Drupal;Flask;Gatsby;Laravel
# 45753  Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 121                                Flask;jQuery;React.js
# 123                                                  NaN
# 191                                                  NaN
# 663                                             React.js
# 697           Angular;ASP.NET;ASP.NET Core;Express;Flask
#
#                                       WebframeWorkedWith  \
# 5701                                              Spring
# 53175                               Express;Flask;jQuery
# 42657                                                NaN
# 58136  Angular;Angular.js;ASP.NET;ASP.NET Core;Expres...
# 45753  Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 121                                               Spring
# 123                                                  NaN
# 191                                                  NaN
# 663                       Express;React.js;Ruby on Rails
# 697                                                  NaN
#
#                                            WelcomeChange  WorkWeekHrs  \
# 5701   Not applicable - I did not use Stack Overflow ...         40.0
# 53175            Just as welcome now as I felt last year         36.0
# 42657            Just as welcome now as I felt last year         40.0
# 58136              A lot more welcome now than last year         40.0
# 45753                                                NaN        168.0
# 121              Just as welcome now as I felt last year         36.0
# 123              Just as welcome now as I felt last year         40.0
# 191              Just as welcome now as I felt last year         40.0
# 663              Just as welcome now as I felt last year         40.0
# 697                                                  NaN         40.0
#
#                 YearsCode        YearsCodePro
# 5701                   10                   4
# 53175                  14                   5
# 42657                  13                   2
# 58136                  20                  14
# 45753  More than 50 years  More than 50 years
# 121                     8                   3
# 123                    11                  11
# 191                    13                   7
# 663                     4    Less than 1 year
# 697                     5                   2

# %%
df.nsmallest(10, 'ConvertedComp')
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 35168       35295  I am a developer by profession     True   NaN         13
# 46385       47357  I am a developer by profession     True   NaN          5
# 6029         6054  I am a developer by profession     True  38.0         15
# 27035       27135  I am a developer by profession    False   NaN         16
# 59118       60292  I am a developer by profession     True   NaN         12
# 38395       38813  I am a developer by profession    False   NaN         18
# 8438         8470  I am a developer by profession     True   NaN          5
# 40410       41006  I am a developer by profession     True  22.0         17
# 15442       15493  I am a developer by profession    False  44.0         17
# 56246       57369  I am a developer by profession    False  44.0         18
#
#       CompFreq  CompTotal  ConvertedComp      Country        CurrencyDesc  \
# 35168  Monthly        2.0            0.0  Afghanistan      Afghan afghani
# 46385   Weekly        1.0            0.0      Albania  Bhutanese ngultrum
# 6029    Yearly        0.0            0.0    Australia   Australian dollar
# 27035   Yearly        0.0            0.0    Australia   Australian dollar
# 59118   Yearly        0.0            0.0      Austria       European Euro
# 38395  Monthly        0.0            0.0   Azerbaijan    Azerbaijan manat
# 8438   Monthly       30.0            0.0   Bangladesh    Bangladeshi taka
# 40410   Yearly        0.0            0.0      Belgium      Pound sterling
# 15442  Monthly        0.0            0.0       Brazil      Brazilian real
# 56246  Monthly        0.0            0.0       Brazil      Brazilian real
#
#       CurrencySymbol                             DatabaseDesireNextYear  \
# 35168            AFN                                                NaN
# 46385            BTN                                            MariaDB
# 6029             AUD                                                NaN
# 27035            AUD                                              MySQL
# 59118            EUR                                                NaN
# 38395            AZN                                                NaN
# 8438             BDT  Elasticsearch;Firebase;MongoDB;MySQL;PostgreSQ...
# 40410            GBP                                                NaN
# 15442            BRL                                           DynamoDB
# 56246            BRL                                           DynamoDB
#
#                                    DatabaseWorkedWith  \
# 35168                         MySQL;PostgreSQL;SQLite
# 46385                                             NaN
# 6029                                            MySQL
# 27035                                           MySQL
# 59118                                             NaN
# 38395                                             NaN
# 8438   Firebase;MongoDB;MySQL;Oracle;PostgreSQL;Redis
# 40410                            Firebase;MySQL;Redis
# 15442                                        DynamoDB
# 56246                                DynamoDB;MongoDB
#
#                                                  DevType  \
# 35168             Academic researcher;Educator;Scientist
# 46385                                Academic researcher
# 6029   Designer;Developer, back-end;Developer, front-...
# 27035                                Senior executive/VP
# 59118                                                NaN
# 38395  Academic researcher;Data or business analyst;D...
# 8438   Developer, back-end;Developer, front-end;Devel...
# 40410  Developer, back-end;Developer, desktop or ente...
# 15442  Developer, back-end;Developer, front-end;Devel...
# 56246                              Developer, full-stack
#
#                                                  EdLevel  \
# 35168         Other doctoral degree (Ph.D., Ed.D., etc.)
# 46385                          Primary/elementary school
# 6029   Secondary school (e.g. American high school, G...
# 27035    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 59118         Other doctoral degree (Ph.D., Ed.D., etc.)
# 38395    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8438        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 40410  Some college/university study without earning ...
# 15442       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56246       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  \
# 35168  Independent contractor, freelancer, or self-em...
# 46385                                 Employed full-time
# 6029   Independent contractor, freelancer, or self-em...
# 27035  Independent contractor, freelancer, or self-em...
# 59118                                 Employed full-time
# 38395                                 Employed full-time
# 8438                                  Employed full-time
# 40410  Independent contractor, freelancer, or self-em...
# 15442  Independent contractor, freelancer, or self-em...
# 56246                                 Employed full-time
#
#                           Ethnicity Gender  \
# 35168                           NaN    NaN
# 46385                           NaN    NaN
# 6029                            NaN    Man
# 27035                           NaN    Man
# 59118                           NaN    NaN
# 38395                           NaN    NaN
# 8438                            NaN    Man
# 40410                Middle Eastern    Man
# 15442  White or of European descent    Man
# 56246                Middle Eastern    Man
#
#                                               JobFactors  \
# 35168                                                NaN
# 46385                                Family friendliness
# 6029   Flex time or a flexible schedule;Languages, fr...
# 27035  Industry that I’d be working in;How widely use...
# 59118                                                NaN
# 38395                                                NaN
# 8438                                                 NaN
# 40410  Languages, frameworks, and other technologies ...
# 15442  Flex time or a flexible schedule;Languages, fr...
# 56246  Flex time or a flexible schedule;Languages, fr...
#
#                                    JobSat  \
# 35168                   Very dissatisfied
# 46385  Neither satisfied nor dissatisfied
# 6029                       Very satisfied
# 27035                      Very satisfied
# 59118                                 NaN
# 38395                   Very dissatisfied
# 8438                                  NaN
# 40410                  Slightly satisfied
# 15442                      Very satisfied
# 56246                      Very satisfied
#
#                                                  JobSeek  \
# 35168                    I am actively looking for a job
# 46385                    I am actively looking for a job
# 6029        I am not interested in new job opportunities
# 27035  I’m not actively looking, but I am open to new...
# 59118                                                NaN
# 38395                                                NaN
# 8438   I’m not actively looking, but I am open to new...
# 40410  I’m not actively looking, but I am open to new...
# 15442  I’m not actively looking, but I am open to new...
# 56246  I’m not actively looking, but I am open to new...
#
#                                   LanguageDesireNextYear  \
# 35168                                                NaN
# 46385                            Bash/Shell/PowerShell;C
# 6029                                                 NaN
# 27035                  Go;HTML/CSS;JavaScript;Python;SQL
# 59118                                                NaN
# 38395                                                NaN
# 8438   Bash/Shell/PowerShell;Dart;Go;JavaScript;Pytho...
# 40410                          C++;Go;Kotlin;Python;Rust
# 15442                                         JavaScript
# 56246                                         JavaScript
#
#                                       LanguageWorkedWith  \
# 35168  Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 46385                                                NaN
# 6029                                                 PHP
# 27035           HTML/CSS;JavaScript;PHP;Python;R;SQL;VBA
# 59118                                                NaN
# 38395                                                NaN
# 8438   Assembly;Bash/Shell/PowerShell;C;HTML/CSS;Java...
# 40410  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 15442                                HTML/CSS;JavaScript
# 56246                                         JavaScript
#
#                                   MiscTechDesireNextYear  \
# 35168                                                NaN
# 46385                                             Hadoop
# 6029                                                 NaN
# 27035  Apache Spark;Node.js;Pandas;TensorFlow;Torch/P...
# 59118                                                NaN
# 38395                                                NaN
# 8438             Flutter;Node.js;React Native;TensorFlow
# 40410                            React Native;TensorFlow
# 15442                      Node.js;React Native;Teraform
# 56246                      Node.js;React Native;Teraform
#
#                                       MiscTechWorkedWith  \
# 35168                                TensorFlow;Unity 3D
# 46385                                                NaN
# 6029                                                 NaN
# 27035  Apache Spark;Node.js;Pandas;TensorFlow;Torch/P...
# 59118                                                NaN
# 38395                                                NaN
# 8438                                             Node.js
# 40410                                  .NET Core;Node.js
# 15442                                            Node.js
# 56246                                            Node.js
#
#                             NEWCollabToolsDesireNextYear  \
# 35168                                                NaN
# 46385                     Google Suite (Docs, Meet, etc)
# 6029                                                 NaN
# 27035                                 Jira;Github;Trello
# 59118                                                NaN
# 38395                                                NaN
# 8438   Jira;Github;Gitlab;Slack;Trello;Google Suite (...
# 40410                                                NaN
# 15442                          Github;Facebook Workplace
# 56246  Github;Gitlab;Facebook Workplace;Trello;Stack ...
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 35168                                                NaN       NaN
# 46385                                                NaN        No
# 6029                                                 NaN        No
# 27035                                 Jira;Github;Trello        No
# 59118                                                NaN       NaN
# 38395                                                NaN       NaN
# 8438   Jira;Github;Gitlab;Slack;Trello;Google Suite (...        No
# 40410  Github;Gitlab;Trello;Google Suite (Docs, Meet,...        No
# 15442                                Github;Slack;Trello        No
# 56246  Github;Slack;Trello;Google Suite (Docs, Meet, ...        No
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 35168                  NaN                      Very important
# 46385  Extremely important                  Somewhat important
# 6029               Neutral  Not at all important/not necessary
# 27035  Extremely important                    Fairly important
# 59118                  NaN                    Fairly important
# 38395                  NaN                Critically important
# 8438   Extremely important                                 NaN
# 40410  Extremely important  Not at all important/not necessary
# 15442  Extremely important                  Somewhat important
# 56246   Somewhat important                  Somewhat important
#
#                                               NEWJobHunt  \
# 35168                                                NaN
# 46385                                       Just because
# 6029                                                 NaN
# 27035  Curious about other opportunities;Better compe...
# 59118                                                NaN
# 38395                                                NaN
# 8438   Curious about other opportunities;Better compe...
# 40410                                                NaN
# 15442  Curious about other opportunities;Better compe...
# 56246  Curious about other opportunities;Better compe...
#
#                                       NEWJobHuntResearch  \
# 35168                                                NaN
# 46385  Read company media, such as employee blogs or ...
# 6029                                                 NaN
# 27035  Read company media, such as employee blogs or ...
# 59118                                                NaN
# 38395                                                NaN
# 8438                                                 NaN
# 40410  Read company media, such as employee blogs or ...
# 15442  Company reviews from third party sites (e.g. G...
# 56246  Read company media, such as employee blogs or ...
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 35168           Once a year         Yes  Onboarding? What onboarding?
# 46385         Once a decade         NaN                           Yes
# 6029   Once every few years    Not sure  Onboarding? What onboarding?
# 27035      Every few months    Not sure  Onboarding? What onboarding?
# 59118                   NaN         NaN                           NaN
# 38395                   NaN    Not sure                           NaN
# 8438       Every few months         NaN                           NaN
# 40410      Every few months    Not sure  Onboarding? What onboarding?
# 15442         Once a decade          No                            No
# 56246         Once a decade          No                            No
#
#       NEWOtherComms                                        NEWOvertime  \
# 35168           Yes                   Often: 1-2 days per week or more
# 46385            No                  Rarely: 1-2 days per year or less
# 6029            Yes                   Often: 1-2 days per week or more
# 27035            No                   Often: 1-2 days per week or more
# 59118           NaN                                                NaN
# 38395           Yes                                                NaN
# 8438            Yes  Occasionally: 1-2 days per quarter but less th...
# 40410            No                   Often: 1-2 days per week or more
# 15442           Yes                   Often: 1-2 days per week or more
# 56246           Yes                   Often: 1-2 days per week or more
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 35168  Read ratings or reviews on third party sites l...  Hello, old friend
# 46385  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 6029                                                 NaN        Indifferent
# 27035  Start a free trial;Visit developer communities...        Indifferent
# 59118                                                NaN                NaN
# 38395                                                NaN                NaN
# 8438                                  Start a free trial                NaN
# 40410  Read ratings or reviews on third party sites l...        Indifferent
# 15442  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 56246  Start a free trial;Visit developer communities...        Indifferent
#
#                                               NEWSOSites  \
# 35168  Stack Overflow (public Q&A for anyone who code...
# 46385   Stack Overflow (public Q&A for anyone who codes)
# 6029   Stack Overflow (public Q&A for anyone who code...
# 27035  Stack Overflow (public Q&A for anyone who code...
# 59118                                                NaN
# 38395  Stack Overflow (public Q&A for anyone who code...
# 8438    Stack Overflow (public Q&A for anyone who codes)
# 40410  Stack Overflow (public Q&A for anyone who code...
# 15442   Stack Overflow (public Q&A for anyone who codes)
# 56246   Stack Overflow (public Q&A for anyone who codes)
#
#                                                 NEWStuck        OpSys  \
# 35168  Play games;Go for a walk or other physical act...  Linux-based
# 46385                                         Play games  Linux-based
# 6029                                                 NaN        MacOS
# 27035  Play games;Visit Stack Overflow;Go for a walk ...      Windows
# 59118                                                NaN          NaN
# 38395                                                NaN          NaN
# 8438                                                 NaN        MacOS
# 40410  Visit Stack Overflow;Panic;Do other work and c...  Linux-based
# 15442  Call a coworker or friend;Visit Stack Overflow...      Windows
# 56246  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                                                  OrgSize  \
# 35168  Just me - I am a freelancer, sole proprietor, ...
# 46385  Just me - I am a freelancer, sole proprietor, ...
# 6029   Just me - I am a freelancer, sole proprietor, ...
# 27035                                   2 to 9 employees
# 59118                           10,000 or more employees
# 38395                                   2 to 9 employees
# 8438                                  20 to 99 employees
# 40410  Just me - I am a freelancer, sole proprietor, ...
# 15442  Just me - I am a freelancer, sole proprietor, ...
# 56246  Just me - I am a freelancer, sole proprietor, ...
#
#                                   PlatformDesireNextYear  \
# 35168                                                NaN
# 46385                                                AWS
# 6029                                                 NaN
# 27035                               Raspberry Pi;Windows
# 59118                                                NaN
# 38395                                                NaN
# 8438   Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 40410                          Android;iOS;MacOS;Windows
# 15442                          AWS;Google Cloud Platform
# 56246                                                AWS
#
#                                   PlatformWorkedWith  \
# 35168                        Android;iOS;Linux;MacOS
# 46385                                            NaN
# 6029                                           MacOS
# 27035     Google Cloud Platform;Raspberry Pi;Windows
# 59118                                            NaN
# 38395                                            NaN
# 8438                       Docker;Heroku;Linux;MacOS
# 40410  Docker;Google Cloud Platform;Kubernetes;Linux
# 15442                                            AWS
# 56246                                            AWS
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 35168                               NaN                      NaN       Yes
# 46385                               NaN                      NaN       Yes
# 6029                                NaN                      NaN       Yes
# 27035                               NaN                      NaN       Yes
# 59118                               NaN                      NaN       NaN
# 38395                               NaN                      NaN       Yes
# 8438                                NaN                      NaN       Yes
# 40410                               NaN                 Bisexual       Yes
# 15442                               NaN  Straight / Heterosexual       Yes
# 56246  I have a great deal of influence  Straight / Heterosexual       Yes
#
#                 SOComm                                         SOPartFreq  \
# 35168   No, not at all                Less than once per month or monthly
# 46385   No, not at all                              Daily or almost daily
# 6029   Yes, definitely                Less than once per month or monthly
# 27035   No, not really  I have never participated in Q&A on Stack Over...
# 59118              NaN                                                NaN
# 38395    Yes, somewhat                Less than once per month or monthly
# 8438     Yes, somewhat                Less than once per month or monthly
# 40410          Neutral                    A few times per month or weekly
# 15442    Yes, somewhat  I have never participated in Q&A on Stack Over...
# 56246    Yes, somewhat  I have never participated in Q&A on Stack Over...
#
#                            SOVisitFreq                  SurveyEase  \
# 35168           Multiple times per day  Neither easy nor difficult
# 46385  A few times per month or weekly                         NaN
# 6029            Multiple times per day                        Easy
# 27035             A few times per week  Neither easy nor difficult
# 59118                              NaN                         NaN
# 38395           Multiple times per day                         NaN
# 8438            Multiple times per day  Neither easy nor difficult
# 40410            Daily or almost daily                        Easy
# 15442            Daily or almost daily                        Easy
# 56246           Multiple times per day                        Easy
#
#                 SurveyLength Trans  \
# 35168  Appropriate in length   NaN
# 46385                    NaN   NaN
# 6029                Too long    No
# 27035  Appropriate in length    No
# 59118                    NaN   NaN
# 38395                    NaN   NaN
# 8438   Appropriate in length    No
# 40410  Appropriate in length    No
# 15442  Appropriate in length    No
# 56246               Too long    No
#
#                                           UndergradMajor  \
# 35168  Another engineering discipline (such as civil,...
# 46385                                                NaN
# 6029                                                 NaN
# 27035  A humanities discipline (such as literature, h...
# 59118  Computer science, computer engineering, or sof...
# 38395  Computer science, computer engineering, or sof...
# 8438   Computer science, computer engineering, or sof...
# 40410  A business discipline (such as accounting, fin...
# 15442  A business discipline (such as accounting, fin...
# 56246  A business discipline (such as accounting, fin...
#
#                          WebframeDesireNextYear  \
# 35168                                       NaN
# 46385                                    Drupal
# 6029                                        NaN
# 27035  Angular.js;Django;jQuery;React.js;Vue.js
# 59118                                       NaN
# 38395                                       NaN
# 8438     Express;Gatsby;Laravel;React.js;Vue.js
# 40410                                       NaN
# 15442                                  React.js
# 56246                                  React.js
#
#                                   WebframeWorkedWith  \
# 35168                                         jQuery
# 46385                                            NaN
# 6029                                         Laravel
# 27035                         Django;jQuery;React.js
# 59118                                            NaN
# 38395                                            NaN
# 8438   Django;Express;Gatsby;Laravel;React.js;Vue.js
# 40410           Angular;ASP.NET Core;React.js;Spring
# 15442                                       React.js
# 56246                                       React.js
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 35168     A lot less welcome now than last year        100.0        35
# 46385  Somewhat less welcome now than last year        168.0         2
# 6029      A lot less welcome now than last year         30.0        22
# 27035   Just as welcome now as I felt last year         80.0        15
# 59118                                       NaN          NaN        18
# 38395     A lot more welcome now than last year          NaN         4
# 8438                                        NaN          NaN         4
# 40410   Just as welcome now as I felt last year         30.0         4
# 15442   Just as welcome now as I felt last year         60.0        10
# 56246   Just as welcome now as I felt last year         60.0        10
#
#       YearsCodePro
# 35168           27
# 46385           11
# 6029            20
# 27035           15
# 59118           10
# 38395            3
# 8438             2
# 40410            3
# 15442            4
# 56246            5

# %% [markdown]
# # 8. Grouping and aggregating

# %%
df.head()
# Out:
#        Respondent                      MainBranch Hobbyist  Age  \
# 61540       62788  I am a developer by profession     True  NaN
# 63925       65381  I am a developer by profession    False  NaN
# 63993       65456  I am a developer by profession     True  NaN
# 38261       38672  I am a developer by profession    False  NaN
# 28270       28374  I am a developer by profession     True  NaN
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 61540                   NaN   Weekly  8.000000e+06      1000000.0
# 63925                     8   Weekly  8.740000e+09      1000000.0
# 63993  Younger than 5 years   Weekly  5.521171e+09      1000000.0
# 38261                     5  Monthly  1.225000e+06       231192.0
# 28270                     7   Yearly  1.300000e+05       130000.0
#
#            Country          CurrencyDesc CurrencySymbol  \
# 61540  Afghanistan          Albanian lek            ALL
# 63925  Afghanistan        Afghan afghani            AFN
# 63993  Afghanistan        Afghan afghani            AFN
# 38261  Afghanistan         Russian ruble            RUB
# 28270  Afghanistan  United States dollar            USD
#
#       DatabaseDesireNextYear DatabaseWorkedWith  \
# 61540                    NaN                NaN
# 63925                    NaN                NaN
# 63993                    NaN                NaN
# 38261                    NaN                NaN
# 28270                 SQLite             SQLite
#
#                                                  DevType  \
# 61540                                          Scientist
# 63925  Data or business analyst;Data scientist or mac...
# 63993                                                NaN
# 38261                                                NaN
# 28270  Developer, desktop or enterprise applications;...
#
#                                           EdLevel  \
# 61540      I never completed any formal education
# 63925      I never completed any formal education
# 63993  Other doctoral degree (Ph.D., Ed.D., etc.)
# 38261      I never completed any formal education
# 28270  Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                               Employment Ethnicity Gender  \
# 61540                                 Employed full-time       NaN    NaN
# 63925  Independent contractor, freelancer, or self-em...       NaN    NaN
# 63993                                 Employed full-time       NaN    NaN
# 38261                                                NaN       NaN    NaN
# 28270                                 Employed full-time       NaN    Man
#
#                                               JobFactors  \
# 61540                                                NaN
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Industry that I’d be working in;Specific depar...
#
#                       JobSat                                       JobSeek  \
# 61540  Slightly dissatisfied               I am actively looking for a job
# 63925      Very dissatisfied                                           NaN
# 63993      Very dissatisfied                                           NaN
# 38261         Very satisfied                                           NaN
# 28270     Slightly satisfied  I am not interested in new job opportunities
#
#         LanguageDesireNextYear                LanguageWorkedWith  \
# 61540                      NaN                               NaN
# 63925                      NaN                               NaN
# 63993                      NaN                               NaN
# 38261                      NaN                               NaN
# 28270  Bash/Shell/PowerShell;C  Bash/Shell/PowerShell;C;C++;Java
#
#       MiscTechDesireNextYear MiscTechWorkedWith NEWCollabToolsDesireNextYear  \
# 61540                    NaN                NaN                          NaN
# 63925                    NaN                NaN                          NaN
# 63993                    NaN                NaN                          NaN
# 38261                    NaN                NaN                          NaN
# 28270                    NaN                NaN                         Jira
#
#       NEWCollabToolsWorkedWith NEWDevOps         NEWDevOpsImpt  \
# 61540                      NaN       NaN    Somewhat important
# 63925                      NaN       Yes  Not at all important
# 63993                      NaN       NaN                   NaN
# 38261                      NaN       NaN                   NaN
# 28270       Jira;Github;Trello       Yes    Somewhat important
#
#                                 NEWEdImpt  \
# 61540                                 NaN
# 63925                                 NaN
# 63993  Not at all important/not necessary
# 38261                                 NaN
# 28270                    Fairly important
#
#                                               NEWJobHunt  \
# 61540                  Curious about other opportunities
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Having a bad day (or week or month) at work;Cu...
#
#                                       NEWJobHuntResearch     NEWLearn  \
# 61540                                                NaN  Once a year
# 63925                                                NaN          NaN
# 63993                                                NaN          NaN
# 38261                                                NaN          NaN
# 28270  Publicly available financial information (e.g....          NaN
#
#       NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 61540         NaN                           Yes            No
# 63925         NaN  Onboarding? What onboarding?           NaN
# 63993         NaN                           NaN           NaN
# 38261         NaN                           NaN           NaN
# 28270         Yes                           Yes           Yes
#
#                                              NEWOvertime  \
# 61540                   Often: 1-2 days per week or more
# 63925                                              Never
# 63993                                                NaN
# 38261                                                NaN
# 28270  Occasionally: 1-2 days per quarter but less th...
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 61540                                                NaN                NaN
# 63925                                                NaN                NaN
# 63993                                                NaN                NaN
# 38261                                                NaN                NaN
# 28270  Visit developer communities like Stack Overflo...  Hello, old friend
#
#                                               NEWSOSites  \
# 61540  Stack Exchange (public Q&A for a variety of to...
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Stack Overflow (public Q&A for anyone who code...
#
#                                              NEWStuck OpSys  \
# 61540                                             NaN   NaN
# 63925                                             NaN   NaN
# 63993                                             NaN   NaN
# 38261                                             NaN   NaN
# 28270  Call a coworker or friend;Visit Stack Overflow   NaN
#
#                                                  OrgSize  \
# 61540                               500 to 999 employees
# 63925  Just me - I am a freelancer, sole proprietor, ...
# 63993  Just me - I am a freelancer, sole proprietor, ...
# 38261  Just me - I am a freelancer, sole proprietor, ...
# 28270                                 20 to 99 employees
#
#       PlatformDesireNextYear PlatformWorkedWith           PurchaseWhat  \
# 61540                    NaN                NaN                    NaN
# 63925                    NaN                NaN                    NaN
# 63993                    NaN                NaN                    NaN
# 38261                    NaN                NaN                    NaN
# 28270                  Linux      Android;Linux  I have some influence
#
#                      Sexuality SOAccount          SOComm SOPartFreq  \
# 61540                      NaN       NaN             NaN        NaN
# 63925                      NaN       NaN             NaN        NaN
# 63993                      NaN       NaN             NaN        NaN
# 38261                      NaN       NaN             NaN        NaN
# 28270  Straight / Heterosexual        No  No, not really        NaN
#
#                   SOVisitFreq                  SurveyEase  \
# 61540                     NaN                         NaN
# 63925                     NaN                         NaN
# 63993                     NaN                         NaN
# 38261                     NaN                         NaN
# 28270  Multiple times per day  Neither easy nor difficult
#
#                 SurveyLength Trans  \
# 61540                    NaN   NaN
# 63925                    NaN   NaN
# 63993                    NaN   NaN
# 38261                    NaN   NaN
# 28270  Appropriate in length    No
#
#                                           UndergradMajor  \
# 61540                                                NaN
# 63925                                                NaN
# 63993  Information systems, information technology, o...
# 38261                                                NaN
# 28270                          Mathematics or statistics
#
#       WebframeDesireNextYear WebframeWorkedWith  \
# 61540                    NaN                NaN
# 63925                    NaN                NaN
# 63993                    NaN                NaN
# 38261                    NaN                NaN
# 28270                    NaN                NaN
#
#                                  WelcomeChange  WorkWeekHrs  \
# 61540                                      NaN          NaN
# 63925                                      NaN          4.0
# 63993                                      NaN          NaN
# 38261                                      NaN          NaN
# 28270  Just as welcome now as I felt last year          NaN
#
#                 YearsCode        YearsCodePro
# 61540                 NaN                 NaN
# 63925                  30                  35
# 63993  More than 50 years  More than 50 years
# 38261                  40                  40
# 28270                  17                   5

# %%
df['ConvertedComp'].head(15)
# Out:
# 61540    1000000.0
# 63925    1000000.0
# 63993    1000000.0
# 38261     231192.0
# 28270     130000.0
# 9806       23328.0
# 62520      23328.0
# 50812      20950.0
# 50469      20220.0
# 43642      18660.0
# 15371      18000.0
# 2918       16335.0
# 26443      13992.0
# 56146      10884.0
# 26676       8016.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Respondent       32231.0
# Hobbyist             1.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# 61540     True
# 63925    False
# 63993     True
# 38261    False
# 28270     True
#          ...
# 64425    False
# 64431     True
# 64434    False
# 64436     True
# 64440    False
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['NEWSOSites']
# Out:
# 61540    Stack Exchange (public Q&A for a variety of to...
# 63925                                                  NaN
# 63993                                                  NaN
# 38261                                                  NaN
# 28270    Stack Overflow (public Q&A for anyone who code...
#                                ...
# 64425                                                  NaN
# 64431                                                  NaN
# 64434                                                  NaN
# 64436                                                  NaN
# 64440                                                  NaN
# Name: NEWSOSites, Length: 64461, dtype: object

# %%
df['NEWSOSites'].value_counts()
# Out:
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                 22415
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                           13891
# Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                                                                                     12762
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                4588
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                    906
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                          585
# I have never visited any of these sites                                                                                                                                                                                                                                                                                528
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)      322
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                     305
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                              209
# Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                                                                  202
# Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                                                                    183
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                            165
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                        161
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                         159
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                            98
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                        66
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                55
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                              51
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                            51
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                46
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                  42
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                               42
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                 33
# Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                                                                33
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                   32
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                    25
# Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                                                                   24
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                               23
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                   21
# Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                                                                 20
# Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                           18
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                     17
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                      17
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                          15
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                       14
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                            14
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                          13
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                             13
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                         11
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                           11
# Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                                     10
# Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                              9
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                   7
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                  7
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                          7
# Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                            6
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                         5
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                     5
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                        4
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                               4
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                           4
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                              4
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                       3
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                   3
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                               3
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                       2
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                  2
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                         2
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                             1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                1
# Name: NEWSOSites, dtype: int64

# %%
df['NEWSOSites'].value_counts(normalize=True)
# Out:
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                 0.384642
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                           0.238370
# Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                                                                                     0.218996
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                               0.078730
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                  0.015547
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                        0.010039
# I have never visited any of these sites                                                                                                                                                                                                                                                                              0.009060
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)    0.005526
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                   0.005234
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                            0.003586
# Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                                                                0.003466
# Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                                                                  0.003140
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                          0.002831
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                      0.002763
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                       0.002728
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                         0.001682
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                     0.001133
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                             0.000944
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                           0.000875
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                         0.000875
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                             0.000789
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                               0.000721
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                            0.000721
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                              0.000566
# Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                                                             0.000566
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                0.000549
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                 0.000429
# Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                                                                0.000412
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                            0.000395
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                0.000360
# Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                                                              0.000343
# Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                        0.000309
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                  0.000292
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                   0.000292
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                       0.000257
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                    0.000240
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                         0.000240
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                       0.000223
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                          0.000223
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                      0.000189
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                        0.000189
# Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                                  0.000172
# Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                          0.000154
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                               0.000120
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                              0.000120
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                      0.000120
# Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                        0.000103
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                     0.000086
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                 0.000086
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                    0.000069
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                           0.000069
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                       0.000069
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                          0.000069
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                   0.000051
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                               0.000051
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                           0.000051
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                   0.000034
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                              0.000034
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                     0.000034
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                         0.000017
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                            0.000017
# Name: NEWSOSites, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Chad                  1
# Kiribati              1
# Fiji                  1
# Gabon                 1
# Mali                  1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 37333       37655                     I am a developer by profession    False
# 36726       36976  I am not primarily a developer, but I write co...    False
# 3318         3332                     I am a developer by profession     True
# 8425         8457                     I am a developer by profession     True
# 21268       21351                     I am a developer by profession    False
# ...           ...                                                ...      ...
# 64391       54757                                                NaN     True
# 64398       55407                                                NaN     True
# 64439       62464                                                NaN     True
# 64442       62954                                                NaN     True
# 64452       64236                                                NaN     True
#
#         Age Age1stCode CompFreq     CompTotal  ConvertedComp Country  \
# 37333   NaN         15  Monthly  1.500000e+05      1800000.0   India
# 36726   NaN         20   Yearly  1.600000e+06      1600000.0   India
# 3318    NaN         19  Monthly  4.200000e+07      1000000.0   India
# 8425   22.0         18  Monthly  7.000000e+06      1000000.0   India
# 21268  98.0         17   Weekly  8.988829e+30      1000000.0   India
# ...     ...        ...      ...           ...            ...     ...
# 64391   NaN         18      NaN           NaN            NaN   India
# 64398   NaN        NaN      NaN           NaN            NaN   India
# 64439   NaN        NaN      NaN           NaN            NaN   India
# 64442   NaN        NaN      NaN           NaN            NaN   India
# 64452   NaN        NaN      NaN           NaN            NaN   India
#
#                CurrencyDesc CurrencySymbol  \
# 37333  United States dollar            USD
# 36726  United States dollar            USD
# 3318           Indian rupee            INR
# 8425           Indian rupee            INR
# 21268         European Euro            EUR
# ...                     ...            ...
# 64391                   NaN            NaN
# 64398                   NaN            NaN
# 64439                   NaN            NaN
# 64442                   NaN            NaN
# 64452                   NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 37333                                           Firebase
# 36726                                                NaN
# 3318   Cassandra;DynamoDB;Elasticsearch;MongoDB;MySQL...
# 8425                          Elasticsearch;MySQL;Oracle
# 21268                                          Cassandra
# ...                                                  ...
# 64391                                      MongoDB;MySQL
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                    DatabaseWorkedWith  \
# 37333   Firebase;Microsoft SQL Server
# 36726                             NaN
# 3318   MongoDB;MySQL;PostgreSQL;Redis
# 8425                     MySQL;Oracle
# 21268                       Cassandra
# ...                               ...
# 64391                           MySQL
# 64398                             NaN
# 64439                             NaN
# 64442                             NaN
# 64452                             NaN
#
#                                                  DevType  \
# 37333  Developer, front-end;Developer, full-stack;Dev...
# 36726  Data or business analyst;Database administrato...
# 3318                                 Developer, back-end
# 8425   Academic researcher;Data scientist or machine ...
# 21268                                                NaN
# ...                                                  ...
# 64391        Developer, full-stack;Developer, QA or test
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                                  EdLevel          Employment  \
# 37333       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 36726    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  Employed full-time
# 3318        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 8425        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 21268  Secondary school (e.g. American high school, G...  Employed full-time
# ...                                                  ...                 ...
# 64391       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed full-time
# 64398                Associate degree (A.A., A.S., etc.)                 NaN
# 64439       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                 NaN
# 64442                                                NaN  Employed full-time
# 64452                                                NaN  Employed full-time
#
#                                                Ethnicity  \
# 37333                                                NaN
# 36726                                                NaN
# 3318                                                 NaN
# 8425                                         South Asian
# 21268  Black or of African descent;East Asian;Hispani...
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                                   Gender  \
# 37333                                                NaN
# 36726                                                NaN
# 3318                                                 NaN
# 8425                                                 Man
# 21268  Non-binary, genderqueer, or gender non-conforming
# ...                                                  ...
# 64391                                                Man
# 64398                                                NaN
# 64439                                                Man
# 64442                                                NaN
# 64452                                                NaN
#
#                                               JobFactors  \
# 37333                                                NaN
# 36726                                                NaN
# 3318   Flex time or a flexible schedule;Specific depa...
# 8425   Flex time or a flexible schedule;Languages, fr...
# 21268                                Family friendliness
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                    JobSat  \
# 37333                  Slightly satisfied
# 36726                      Very satisfied
# 3318   Neither satisfied nor dissatisfied
# 8425                Slightly dissatisfied
# 21268                   Very dissatisfied
# ...                                   ...
# 64391                                 NaN
# 64398                                 NaN
# 64439                                 NaN
# 64442                                 NaN
# 64452                                 NaN
#
#                                                  JobSeek  \
# 37333                                                NaN
# 36726                                                NaN
# 3318   I’m not actively looking, but I am open to new...
# 8425                     I am actively looking for a job
# 21268                    I am actively looking for a job
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                     LanguageDesireNextYear  \
# 37333              Dart;Objective-C;Python
# 36726                                  NaN
# 3318   Go;Java;JavaScript;Python;Scala;SQL
# 8425                     C;C++;Java;Python
# 21268                Bash/Shell/PowerShell
# ...                                    ...
# 64391  HTML/CSS;Java;JavaScript;Python;SQL
# 64398                                  NaN
# 64439                                  NaN
# 64442                                  NaN
# 64452                                  NaN
#
#                               LanguageWorkedWith  \
# 37333  C#;Dart;Java;Objective-C;Python;SQL;Swift
# 36726                                        NaN
# 3318                    Go;Java;Python;Scala;SQL
# 8425     Assembly;C;C++;HTML/CSS;Java;Python;SQL
# 21268                      Bash/Shell/PowerShell
# ...                                          ...
# 64391  C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 64398                                        NaN
# 64439                                        NaN
# 64442                                        SQL
# 64452                                        NaN
#
#                                 MiscTechDesireNextYear  \
# 37333                               Flutter;TensorFlow
# 36726                                              NaN
# 3318   Apache Spark;Node.js;Pandas;TensorFlow;Teraform
# 8425                                               NaN
# 21268                                          Xamarin
# ...                                                ...
# 64391                                              NaN
# 64398                                              NaN
# 64439                                              NaN
# 64442                                              NaN
# 64452                                              NaN
#
#                                       MiscTechWorkedWith  \
# 37333  .NET;Flutter;Node.js;React Native;TensorFlow;X...
# 36726                                                NaN
# 3318      Ansible;Apache Spark;Node.js;Pandas;TensorFlow
# 8425                                                 NaN
# 21268                                            Xamarin
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                             NEWCollabToolsDesireNextYear  \
# 37333             Confluence;Jira;Github;Microsoft Teams
# 36726                                                NaN
# 3318                 Github;Slack;Microsoft Azure;Trello
# 8425   Github;Microsoft Teams;Google Suite (Docs, Mee...
# 21268                                               Jira
# ...                                                  ...
# 64391                           Jira;Github;Gitlab;Slack
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 37333  Confluence;Jira;Github;Microsoft Teams;Trello;...       Yes
# 36726                                                NaN        No
# 3318   Confluence;Jira;Github;Slack;Microsoft Azure;T...        No
# 8425   Github;Microsoft Teams;Google Suite (Docs, Mee...        No
# 21268                                               Jira       Yes
# ...                                                  ...       ...
# 64391                           Jira;Github;Gitlab;Slack       NaN
# 64398                                                NaN       NaN
# 64439                                                NaN       NaN
# 64442                                                NaN       NaN
# 64452                                                NaN       NaN
#
#              NEWDevOpsImpt                           NEWEdImpt  \
# 37333              Neutral                      Very important
# 36726              Neutral                Critically important
# 3318               Neutral                    Fairly important
# 8425               Neutral                Critically important
# 21268  Extremely important  Not at all important/not necessary
# ...                    ...                                 ...
# 64391                  NaN                                 NaN
# 64398                  NaN                                 NaN
# 64439                  NaN                                 NaN
# 64442                  NaN                                 NaN
# 64452                  NaN                                 NaN
#
#                                               NEWJobHunt  \
# 37333                                                NaN
# 36726                                                NaN
# 3318   Just because;Better compensation;Trouble with ...
# 8425   Wanting to share accomplishments with a wider ...
# 21268                                       Just because
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                       NEWJobHuntResearch  \
# 37333                                                NaN
# 36726                                                NaN
# 3318   Company reviews from third party sites (e.g. G...
# 8425   Read company media, such as employee blogs or ...
# 21268                                                NaN
# ...                                                  ...
# 64391                                                NaN
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                    NEWLearn NEWOffTopic                NEWOnboardGood  \
# 37333      Every few months         NaN                           Yes
# 36726                   NaN         NaN                           Yes
# 3318       Every few months          No                            No
# 8425   Once every few years         NaN                            No
# 21268         Once a decade         NaN  Onboarding? What onboarding?
# ...                     ...         ...                           ...
# 64391           Once a year          No                           NaN
# 64398                   NaN         NaN                           NaN
# 64439                   NaN         NaN                           NaN
# 64442                   NaN         NaN                           NaN
# 64452                   NaN         NaN                           NaN
#
#       NEWOtherComms                                        NEWOvertime  \
# 37333           NaN  Sometimes: 1-2 days per month but less than we...
# 36726           NaN                   Often: 1-2 days per week or more
# 3318            Yes  Sometimes: 1-2 days per month but less than we...
# 8425             No                   Often: 1-2 days per week or more
# 21268            No                                              Never
# ...             ...                                                ...
# 64391           NaN                                                NaN
# 64398           NaN                                                NaN
# 64439           NaN                                                NaN
# 64442           NaN                                                NaN
# 64452           NaN                                                NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 37333                                                NaN             Amused
# 36726                                                NaN                NaN
# 3318   Start a free trial;Ask developers I know/work ...        Indifferent
# 8425   Start a free trial;Ask developers I know/work ...            Annoyed
# 21268                                                NaN  Hello, old friend
# ...                                                  ...                ...
# 64391                    Ask developers I know/work with             Amused
# 64398                                                NaN                NaN
# 64439                                                NaN                NaN
# 64442                                                NaN                NaN
# 64452                                                NaN                NaN
#
#                                               NEWSOSites  \
# 37333                                                NaN
# 36726                                                NaN
# 3318   Stack Overflow (public Q&A for anyone who code...
# 8425             I have never visited any of these sites
# 21268            I have never visited any of these sites
# ...                                                  ...
# 64391  Stack Overflow (public Q&A for anyone who code...
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                                 NEWStuck        OpSys  \
# 37333  Play games;Visit Stack Overflow;Go for a walk ...        MacOS
# 36726                                                NaN          NaN
# 3318   Call a coworker or friend;Visit Stack Overflow...        MacOS
# 8425   Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 21268                                              Panic          BSD
# ...                                                  ...          ...
# 64391                               Visit Stack Overflow  Linux-based
# 64398                                                NaN          NaN
# 64439                                                NaN          NaN
# 64442                                                NaN          NaN
# 64452                                                NaN          NaN
#
#                         OrgSize  \
# 37333      500 to 999 employees
# 36726      100 to 499 employees
# 3318   10,000 or more employees
# 8425         20 to 99 employees
# 21268                       NaN
# ...                         ...
# 64391                       NaN
# 64398                       NaN
# 64439                       NaN
# 64442                       NaN
# 64452                       NaN
#
#                                   PlatformDesireNextYear  \
# 37333                           Android;iOS;Raspberry Pi
# 36726                                                NaN
# 3318   AWS;Docker;Google Cloud Platform;Heroku;Kubern...
# 8425   AWS;Google Cloud Platform;IBM Cloud or Watson;...
# 21268                                          WordPress
# ...                                                  ...
# 64391                                      Linux;Windows
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                                       PlatformWorkedWith  \
# 37333  Android;Google Cloud Platform;iOS;Raspberry Pi...
# 36726                                                NaN
# 3318   AWS;Docker;Kubernetes;Linux;MacOS;Microsoft Azure
# 8425                                       Linux;Windows
# 21268                                          WordPress
# ...                                                  ...
# 64391                                      Linux;Windows
# 64398                                                NaN
# 64439                                                NaN
# 64442                                                NaN
# 64452                                                NaN
#
#                            PurchaseWhat                Sexuality  \
# 37333     I have little or no influence                      NaN
# 36726                               NaN                      NaN
# 3318              I have some influence                      NaN
# 8425   I have a great deal of influence                      NaN
# 21268     I have little or no influence                    Queer
# ...                                 ...                      ...
# 64391                               NaN  Straight / Heterosexual
# 64398                               NaN                      NaN
# 64439                               NaN                      NaN
# 64442                               NaN                      NaN
# 64452                               NaN                      NaN
#
#                      SOAccount           SOComm             SOPartFreq  \
# 37333                      NaN              NaN                    NaN
# 36726                      NaN              NaN                    NaN
# 3318                       Yes  Yes, definitely  Daily or almost daily
# 8425                       NaN              NaN                    NaN
# 21268                      NaN              NaN                    NaN
# ...                        ...              ...                    ...
# 64391  Not sure/can't remember          Neutral                    NaN
# 64398                      NaN              NaN                    NaN
# 64439                      NaN              NaN                    NaN
# 64442                      NaN              NaN                    NaN
# 64452                      NaN              NaN                    NaN
#
#                            SOVisitFreq                  SurveyEase  \
# 37333                              NaN                         NaN
# 36726                              NaN                         NaN
# 3318             Daily or almost daily  Neither easy nor difficult
# 8425                               NaN  Neither easy nor difficult
# 21268                              NaN                        Easy
# ...                                ...                         ...
# 64391  A few times per month or weekly                        Easy
# 64398                              NaN                         NaN
# 64439                              NaN                         NaN
# 64442                              NaN                         NaN
# 64452                              NaN                         NaN
#
#                 SurveyLength Trans  \
# 37333                    NaN   NaN
# 36726                    NaN   NaN
# 3318   Appropriate in length   NaN
# 8425                Too long    No
# 21268              Too short   NaN
# ...                      ...   ...
# 64391  Appropriate in length    No
# 64398                    NaN   NaN
# 64439                    NaN   NaN
# 64442                    NaN   NaN
# 64452                    NaN   NaN
#
#                                           UndergradMajor  \
# 37333  Computer science, computer engineering, or sof...
# 36726  Computer science, computer engineering, or sof...
# 3318   Computer science, computer engineering, or sof...
# 8425   Computer science, computer engineering, or sof...
# 21268                                                NaN
# ...                                                  ...
# 64391  Computer science, computer engineering, or sof...
# 64398                                                NaN
# 64439                           I never declared a major
# 64442                                                NaN
# 64452                                                NaN
#
#       WebframeDesireNextYear  \
# 37333                Express
# 36726                    NaN
# 3318     Django;Flask;Spring
# 8425                 Angular
# 21268                 jQuery
# ...                      ...
# 64391                 jQuery
# 64398                    NaN
# 64439                    NaN
# 64442                    NaN
# 64452                    NaN
#
#                                       WebframeWorkedWith  \
# 37333                                    ASP.NET;Express
# 36726                                                NaN
# 3318                                        Flask;Spring
# 8425                                                 NaN
# 21268                                             jQuery
# ...                                                  ...
# 64391                                             jQuery
# 64398                                                NaN
# 64439                                                NaN
# 64442  ASP.NET;ASP.NET Core;Django;jQuery;Symfony;Vue.js
# 64452                                                NaN
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 37333                                       NaN         40.0        13
# 36726                                       NaN         50.0        15
# 3318   Somewhat less welcome now than last year         35.0         7
# 8425                                        NaN         45.0         4
# 21268                                       NaN          1.0         6
# ...                                         ...          ...       ...
# 64391     A lot less welcome now than last year          NaN         5
# 64398                                       NaN          NaN       NaN
# 64439                                       NaN          NaN       NaN
# 64442                                       NaN          NaN       NaN
# 64452                                       NaN          NaN       NaN
#
#            YearsCodePro
# 37333                10
# 36726                10
# 3318                  3
# 8425   Less than 1 year
# 21268                 6
# ...                 ...
# 64391  Less than 1 year
# 64398               NaN
# 64439               NaN
# 64442               NaN
# 64452               NaN
#
# [8403 rows x 61 columns]

# %%
filt = df['Country'] == 'India'
df.loc[filt]['NEWSOSites'].value_counts()
# Out:
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                 2323
# Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                                                                                     1627
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                           1568
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                601
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                   127
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)     113
# I have never visited any of these sites                                                                                                                                                                                                                                                                                71
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                     64
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                          59
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                            58
# Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                                                                  54
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                         50
# Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                                                                    33
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                           29
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                              29
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                        26
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                               19
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                               17
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                             15
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                  13
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                12
# Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                                                                11
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                        9
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                            9
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                               9
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                  8
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                             8
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                               7
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                    7
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                      7
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                       7
# Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                                                                6
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                            6
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                   5
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                     4
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                          4
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                    3
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                          3
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                 3
# Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                           2
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                           2
# Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                             2
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                         2
# Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                                                                   2
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                  2
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                              2
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                         1
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                          1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                      1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                             1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                 1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                       1
# Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                           1
# Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                        1
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                                                                  1
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                        1
# Name: NEWSOSites, dtype: int64

# %%
country_grp['NEWSOSites'].value_counts(normalize=True).loc['China']
# Out:
# NEWSOSites
# Stack Overflow (public Q&A for anyone who codes)                                                                                                                                                                                                                                                                     0.382353
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                 0.333333
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers)                                                                                                                                                                           0.101307
# I have never visited any of these sites                                                                                                                                                                                                                                                                              0.045752
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                               0.035948
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)    0.016340
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                  0.009804
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                   0.006536
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                          0.006536
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                        0.006536
# Stack Overflow Jobs (for job seekers)                                                                                                                                                                                                                                                                                0.006536
# Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                                                             0.006536
# Stack Exchange (public Q&A for a variety of topics)                                                                                                                                                                                                                                                                  0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Advertising (for technology companies)                                                                                                                                                           0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                         0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                  0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Exchange (public Q&A for a variety of topics);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                          0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                      0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                              0.003268
# Stack Overflow (public Q&A for anyone who codes);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                    0.003268
# Stack Overflow Jobs (for job seekers);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                                          0.003268
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations)                                                                                                                                                                                                                       0.003268
# Stack Overflow Jobs (for job seekers);Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Talent (for hiring companies/recruiters);Stack Overflow Advertising (for technology companies)                                                                                                         0.003268
# Stack Overflow Talent (for hiring companies/recruiters)                                                                                                                                                                                                                                                              0.003268
# Stack Overflow for Teams (private Q&A for organizations);Stack Overflow Advertising (for technology companies)                                                                                                                                                                                                       0.003268
# Name: NEWSOSites, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Chad                  1
# Kiribati              1
# Fiji                  1
# Gabon                 1
# Mali                  1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Chad                  1                   0
# Kiribati              1                   0
# Fiji                  1                   0
# Gabon                 1                   1
# Mali                  1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12469            5964
# India                     8403            2670
# United Kingdom            3896            1621
# Germany                   3890            1712
# Canada                    2191            1011
# ...                        ...             ...
# Chad                         1               0
# Kiribati                     1               0
# Fiji                         1               0
# Gabon                        1               1
# Mali                         1               0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States            12469            5964       47.830620
# India                     8403            2670       31.774366
# United Kingdom            3896            1621       41.606776
# Germany                   3890            1712       44.010283
# Canada                    2191            1011       46.143314
# ...                        ...             ...             ...
# Chad                         1               0        0.000000
# Kiribati                     1               0        0.000000
# Fiji                         1               0        0.000000
# Gabon                        1               1      100.000000
# Mali                         1               0        0.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Gabon                                              1               1
# Saint Lucia                                        1               1
# Micronesia, Federated States of...                 1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Burkina Faso                                       6               3
# Jamaica                                           14               7
# Belize                                             4               2
# Mauritania                                         4               2
# Solomon Islands                                    2               1
# Papua New Guinea                                   2               1
# Timor-Leste                                        2               1
# Cameroon                                          50              24
# United States                                  12469            5964
# Israel                                           653             307
# Ecuador                                           49              23
# Taiwan                                           158              73
# Canada                                          2191            1011
# Oman                                              11               5
# Estonia                                          145              65
# Ireland                                          444             199
# Japan                                            297             132
# Switzerland                                      629             278
# Germany                                         3890            1712
# France                                          1898             833
# Costa Rica                                        76              33
# Singapore                                        228              99
# Australia                                       1208             524
# Democratic Republic of the Congo                   7               3
# Lao People's Democratic Republic                   7               3
# Trinidad and Tobago                                7               3
# China                                            371             158
# Peru                                             101              43
# Algeria                                           94              40
# Malta                                             47              20
# Zimbabwe                                          31              13
# Norway                                           384             160
# New Zealand                                      353             147
# United Kingdom                                  3896            1621
# Hong Kong (S.A.R.)                               111              46
# Venezuela, Bolivarian Republic of...              70              29
# Slovenia                                         157              65
# Kenya                                            271             111
# Netherlands                                     1343             544
# Qatar                                             20               8
#
#                                       PctKnowsPython
# Gabon                                     100.000000
# Saint Lucia                               100.000000
# Micronesia, Federated States of...        100.000000
# Montenegro                                 69.230769
# Brunei Darussalam                          66.666667
# Guyana                                     60.000000
# Swaziland                                  57.142857
# Iceland                                    52.830189
# Finland                                    52.435530
# Uganda                                     51.851852
# Burkina Faso                               50.000000
# Jamaica                                    50.000000
# Belize                                     50.000000
# Mauritania                                 50.000000
# Solomon Islands                            50.000000
# Papua New Guinea                           50.000000
# Timor-Leste                                50.000000
# Cameroon                                   48.000000
# United States                              47.830620
# Israel                                     47.013783
# Ecuador                                    46.938776
# Taiwan                                     46.202532
# Canada                                     46.143314
# Oman                                       45.454545
# Estonia                                    44.827586
# Ireland                                    44.819820
# Japan                                      44.444444
# Switzerland                                44.197138
# Germany                                    44.010283
# France                                     43.888303
# Costa Rica                                 43.421053
# Singapore                                  43.421053
# Australia                                  43.377483
# Democratic Republic of the Congo           42.857143
# Lao People's Democratic Republic           42.857143
# Trinidad and Tobago                        42.857143
# China                                      42.587601
# Peru                                       42.574257
# Algeria                                    42.553191
# Malta                                      42.553191
# Zimbabwe                                   41.935484
# Norway                                     41.666667
# New Zealand                                41.643059
# United Kingdom                             41.606776
# Hong Kong (S.A.R.)                         41.441441
# Venezuela, Bolivarian Republic of...       41.428571
# Slovenia                                   41.401274
# Kenya                                      40.959410
# Netherlands                                40.506329
# Qatar                                      40.000000

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64

# %% [markdown]
# # 9 cleaning data

# %%
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

df_test = pd.DataFrame(people)

# %%
df_test.replace('NA', np.nan, inplace=True)
df_test.replace('Missing', np.nan, inplace=True)

df_test
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df_test.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df_test.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df_test.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df_test.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df_test.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
# df_test['age'].mean()

# %%
df_test['age'] = df_test['age'].astype(float)

# %%
df_test.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df_test['age'].mean()
# Out:
# 46.75

# %% [markdown]
# ## applying on real data

# %%
na_vals = ['NA', 'Missing']

# %%
df.head()
# Out:
#        Respondent                      MainBranch Hobbyist  Age  \
# 61540       62788  I am a developer by profession     True  NaN
# 63925       65381  I am a developer by profession    False  NaN
# 63993       65456  I am a developer by profession     True  NaN
# 38261       38672  I am a developer by profession    False  NaN
# 28270       28374  I am a developer by profession     True  NaN
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 61540                   NaN   Weekly  8.000000e+06      1000000.0
# 63925                     8   Weekly  8.740000e+09      1000000.0
# 63993  Younger than 5 years   Weekly  5.521171e+09      1000000.0
# 38261                     5  Monthly  1.225000e+06       231192.0
# 28270                     7   Yearly  1.300000e+05       130000.0
#
#            Country          CurrencyDesc CurrencySymbol  \
# 61540  Afghanistan          Albanian lek            ALL
# 63925  Afghanistan        Afghan afghani            AFN
# 63993  Afghanistan        Afghan afghani            AFN
# 38261  Afghanistan         Russian ruble            RUB
# 28270  Afghanistan  United States dollar            USD
#
#       DatabaseDesireNextYear DatabaseWorkedWith  \
# 61540                    NaN                NaN
# 63925                    NaN                NaN
# 63993                    NaN                NaN
# 38261                    NaN                NaN
# 28270                 SQLite             SQLite
#
#                                                  DevType  \
# 61540                                          Scientist
# 63925  Data or business analyst;Data scientist or mac...
# 63993                                                NaN
# 38261                                                NaN
# 28270  Developer, desktop or enterprise applications;...
#
#                                           EdLevel  \
# 61540      I never completed any formal education
# 63925      I never completed any formal education
# 63993  Other doctoral degree (Ph.D., Ed.D., etc.)
# 38261      I never completed any formal education
# 28270  Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                               Employment Ethnicity Gender  \
# 61540                                 Employed full-time       NaN    NaN
# 63925  Independent contractor, freelancer, or self-em...       NaN    NaN
# 63993                                 Employed full-time       NaN    NaN
# 38261                                                NaN       NaN    NaN
# 28270                                 Employed full-time       NaN    Man
#
#                                               JobFactors  \
# 61540                                                NaN
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Industry that I’d be working in;Specific depar...
#
#                       JobSat                                       JobSeek  \
# 61540  Slightly dissatisfied               I am actively looking for a job
# 63925      Very dissatisfied                                           NaN
# 63993      Very dissatisfied                                           NaN
# 38261         Very satisfied                                           NaN
# 28270     Slightly satisfied  I am not interested in new job opportunities
#
#         LanguageDesireNextYear                LanguageWorkedWith  \
# 61540                      NaN                               NaN
# 63925                      NaN                               NaN
# 63993                      NaN                               NaN
# 38261                      NaN                               NaN
# 28270  Bash/Shell/PowerShell;C  Bash/Shell/PowerShell;C;C++;Java
#
#       MiscTechDesireNextYear MiscTechWorkedWith NEWCollabToolsDesireNextYear  \
# 61540                    NaN                NaN                          NaN
# 63925                    NaN                NaN                          NaN
# 63993                    NaN                NaN                          NaN
# 38261                    NaN                NaN                          NaN
# 28270                    NaN                NaN                         Jira
#
#       NEWCollabToolsWorkedWith NEWDevOps         NEWDevOpsImpt  \
# 61540                      NaN       NaN    Somewhat important
# 63925                      NaN       Yes  Not at all important
# 63993                      NaN       NaN                   NaN
# 38261                      NaN       NaN                   NaN
# 28270       Jira;Github;Trello       Yes    Somewhat important
#
#                                 NEWEdImpt  \
# 61540                                 NaN
# 63925                                 NaN
# 63993  Not at all important/not necessary
# 38261                                 NaN
# 28270                    Fairly important
#
#                                               NEWJobHunt  \
# 61540                  Curious about other opportunities
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Having a bad day (or week or month) at work;Cu...
#
#                                       NEWJobHuntResearch     NEWLearn  \
# 61540                                                NaN  Once a year
# 63925                                                NaN          NaN
# 63993                                                NaN          NaN
# 38261                                                NaN          NaN
# 28270  Publicly available financial information (e.g....          NaN
#
#       NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 61540         NaN                           Yes            No
# 63925         NaN  Onboarding? What onboarding?           NaN
# 63993         NaN                           NaN           NaN
# 38261         NaN                           NaN           NaN
# 28270         Yes                           Yes           Yes
#
#                                              NEWOvertime  \
# 61540                   Often: 1-2 days per week or more
# 63925                                              Never
# 63993                                                NaN
# 38261                                                NaN
# 28270  Occasionally: 1-2 days per quarter but less th...
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 61540                                                NaN                NaN
# 63925                                                NaN                NaN
# 63993                                                NaN                NaN
# 38261                                                NaN                NaN
# 28270  Visit developer communities like Stack Overflo...  Hello, old friend
#
#                                               NEWSOSites  \
# 61540  Stack Exchange (public Q&A for a variety of to...
# 63925                                                NaN
# 63993                                                NaN
# 38261                                                NaN
# 28270  Stack Overflow (public Q&A for anyone who code...
#
#                                              NEWStuck OpSys  \
# 61540                                             NaN   NaN
# 63925                                             NaN   NaN
# 63993                                             NaN   NaN
# 38261                                             NaN   NaN
# 28270  Call a coworker or friend;Visit Stack Overflow   NaN
#
#                                                  OrgSize  \
# 61540                               500 to 999 employees
# 63925  Just me - I am a freelancer, sole proprietor, ...
# 63993  Just me - I am a freelancer, sole proprietor, ...
# 38261  Just me - I am a freelancer, sole proprietor, ...
# 28270                                 20 to 99 employees
#
#       PlatformDesireNextYear PlatformWorkedWith           PurchaseWhat  \
# 61540                    NaN                NaN                    NaN
# 63925                    NaN                NaN                    NaN
# 63993                    NaN                NaN                    NaN
# 38261                    NaN                NaN                    NaN
# 28270                  Linux      Android;Linux  I have some influence
#
#                      Sexuality SOAccount          SOComm SOPartFreq  \
# 61540                      NaN       NaN             NaN        NaN
# 63925                      NaN       NaN             NaN        NaN
# 63993                      NaN       NaN             NaN        NaN
# 38261                      NaN       NaN             NaN        NaN
# 28270  Straight / Heterosexual        No  No, not really        NaN
#
#                   SOVisitFreq                  SurveyEase  \
# 61540                     NaN                         NaN
# 63925                     NaN                         NaN
# 63993                     NaN                         NaN
# 38261                     NaN                         NaN
# 28270  Multiple times per day  Neither easy nor difficult
#
#                 SurveyLength Trans  \
# 61540                    NaN   NaN
# 63925                    NaN   NaN
# 63993                    NaN   NaN
# 38261                    NaN   NaN
# 28270  Appropriate in length    No
#
#                                           UndergradMajor  \
# 61540                                                NaN
# 63925                                                NaN
# 63993  Information systems, information technology, o...
# 38261                                                NaN
# 28270                          Mathematics or statistics
#
#       WebframeDesireNextYear WebframeWorkedWith  \
# 61540                    NaN                NaN
# 63925                    NaN                NaN
# 63993                    NaN                NaN
# 38261                    NaN                NaN
# 28270                    NaN                NaN
#
#                                  WelcomeChange  WorkWeekHrs  \
# 61540                                      NaN          NaN
# 63925                                      NaN          4.0
# 63993                                      NaN          NaN
# 38261                                      NaN          NaN
# 28270  Just as welcome now as I felt last year          NaN
#
#                 YearsCode        YearsCodePro
# 61540                 NaN                 NaN
# 63925                  30                  35
# 63993  More than 50 years  More than 50 years
# 38261                  40                  40
# 28270                  17                   5

# %%
df['YearsCode'].head(10)
# Out:
# 61540                   NaN
# 63925                    30
# 63993    More than 50 years
# 38261                    40
# 28270                    17
# 9806                     10
# 62520                    14
# 50812                     5
# 50469                     8
# 43642                     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '30', 'More than 50 years', '40', '17', '10', '14', '5', '8',
#        '9', '4', '6', '3', '2', '35', '1', 'Less than 1 year', '7', '12',
#        '50', '19', '20', '11', '15', '24', '27', '28', '16', '22', '13',
#        '18', '25', '38', '34', '23', '32', '21', '42', '33', '26', '29',
#        '39', '48', '36', '47', '41', '37', '31', '43', '44', '45', '46',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0
